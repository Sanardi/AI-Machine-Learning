# %%
import requests
from requests.auth import HTTPBasicAuth
import PIL

# %%
from PIL import Image
from io import BytesIO


payload = {"zipcode": "82"}
r = requests.get('https://monitor.datusedcardb.com/testplot.png', params = payload, auth=HTTPBasicAuth('user', 'password'))


i = Image.open(BytesIO(r.content))

# %%
display(i)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x800 at 0x7FD6B3369F10>
