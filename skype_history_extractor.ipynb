# %% [markdown]
# # This Python script can be used to extract the Skype chat context by Skype ID for Chatbot input generation, etc. Feel free to re-use this code, but please quote the Author --Marzia Catherine Azam-- Github: https://github.com/Sanardi

# %%
import json
myjson = 'data\hamadeskype.json'
data = json.load(open(myjson, 'r', encoding="utf8"))
data
# Out:
# {'userId': '8:live:.cid.8136fa355186e318',
#  'exportDate': '2021-05-22T12:04',
#  'conversations': [{'id': '8:live:rubypromise',
#    'displayName': 'Marzia Azam',
#    'version': 1621684960158.0,
#    'properties': {'conversationblocked': False,
#     'lastimreceivedtime': '2021-05-22T12:02:32.236Z',
#     'consumptionhorizon': '1621684953987;1621684959443;8509377565427466708',
#     'conversationstatus': 'Accepted'},
#    'threadProperties': None,
#    'MessageList': [{'id': '1621684953987',
#      'displayName': 'Marzia Azam',
#      'originalarrivaltime': '2021-05-22T12:02:32.236Z',
#      'messagetype': 'RichText',
#      'version': 1621684953987.0,
#      'content': '<a href="https://support.skype.com/en/faq/FA34894/how-do-i-export-my-skype-files-and-chat-history">https://support.skype.com/en/faq/FA34894/how-do-i-export-my-skype-files-and-chat-history</a>',
#      'conversationid': '8:live:rubypromise',
#      'from': '8:live:rubypromise',
# ...

# %%
asdict = data["conversations"]
asdict
# Out:
# [{'id': '8:live:rubypromise',
#   'displayName': 'Marzia Azam',
#   'version': 1621684960158.0,
#   'properties': {'conversationblocked': False,
#    'lastimreceivedtime': '2021-05-22T12:02:32.236Z',
#    'consumptionhorizon': '1621684953987;1621684959443;8509377565427466708',
#    'conversationstatus': 'Accepted'},
#   'threadProperties': None,
#   'MessageList': [{'id': '1621684953987',
#     'displayName': 'Marzia Azam',
#     'originalarrivaltime': '2021-05-22T12:02:32.236Z',
#     'messagetype': 'RichText',
#     'version': 1621684953987.0,
#     'content': '<a href="https://support.skype.com/en/faq/FA34894/how-do-i-export-my-skype-files-and-chat-history">https://support.skype.com/en/faq/FA34894/how-do-i-export-my-skype-files-and-chat-history</a>',
#     'conversationid': '8:live:rubypromise',
#     'from': '8:live:rubypromise',
# ...

# %% [markdown]
# Now we pass the name of the person for whom we want to extract the chat history:

# %%
#search for: 'conversationid': '8:ayman.hamade46'
person_name = '8:ayman.hamade46'

#filter to just see text messages:
messagetype =  'RichText'
skypehamade = [chat for chat in asdict if person_name in chat.values()]

#skypehamade = [chat for chat in asdict if messagetype in chat.values()]
skypehamade
# Out:
# [{'id': '8:ayman.hamade46',
#   'displayName': 'Deeseh',
#   'version': 1621418856952.0,
#   'properties': {'conversationblocked': False,
#    'lastimreceivedtime': '2021-05-14T17:07:57.244Z',
#    'consumptionhorizon': '1621418856264;1621418856518;1130511666038010653',
#    'conversationstatus': 'Accepted'},
#   'threadProperties': None,
#   'MessageList': [{'id': '1621418856264',
#     'displayName': None,
#     'originalarrivaltime': '2021-05-19T10:07:35.97Z',
#     'messagetype': 'Event/Call',
#     'version': 1621418856264.0,
#     'content': '<partlist type="missed" alt="" callId="418b7e1d-7fdf-464b-9914-0cdb047a2242"><part identity="live:.cid.8136fa355186e318"><name>mustafa hhh</name></part><part identity="ayman.hamade46"><name>Deeseh</name></part></partlist>',
#     'conversationid': '8:ayman.hamade46',
#     'from': '8:live:.cid.8136fa355186e318',
#     'properties': None,
#     'amsreferences': None},
#    {'id': '1621155295113',
#     'displayName': None,
# ...

# %%
import json

skype_content= []

import json
def get_all(myjson, key):
    if type(myjson) == str:
        myjson = json.load(open(myjson, 'r', encoding="utf8"))
    if type(myjson) is dict:
        for jsonkey in myjson:
            if type(myjson[jsonkey]) in (list, dict):
                get_all(myjson[jsonkey], key)
            elif jsonkey == key:
                skype_content.append(myjson[jsonkey])
    elif type(myjson) is list:
        for item in myjson:
            if type(item) in (list, dict):
                get_all(item, key)
                
get_all(skypehamade, "content")
skype_content
# Out:
# ['<partlist type="missed" alt="" callId="418b7e1d-7fdf-464b-9914-0cdb047a2242"><part identity="live:.cid.8136fa355186e318"><name>mustafa hhh</name></part><part identity="ayman.hamade46"><name>Deeseh</name></part></partlist>',
#  '<partlist type="missed" alt="" callId="0bc1744a-fa3f-4fa6-8a90-d5ad8a0d895c"><part identity="live:.cid.8136fa355186e318"><name>mustafa hhh</name></part><part identity="ayman.hamade46"><name>Deeseh</name></part></partlist>',
#  '<partlist type="missed" alt="" callId="d2c69644-b820-45f6-b1b4-b8651d32dbcf"><part identity="live:.cid.8136fa355186e318"><name>mustafa hhh</name></part><part identity="ayman.hamade46"><name>Deeseh</name></part></partlist>',
#  'we are getting air bnb 1000eur for self isolation + 500 for trip, 300 for covid tests, the solisiter says you will have to cover this, plus mamas loss in earnings for having to take ahmad to hospital in UK',
# ...

# %%
exclusion_list = ["<partlist", "URIObject", "Call Log", "<topicupdate>", "</e_m>", "callId" ]

''''
def skype_clean(chat_history, exclusion_list):
    skype_clean = []
    for word in exclusions_listl:, 
        skype_clean =[item for item in chat_history if word not in item]
        return skype_clean
   
#The above code works but is slower so I use list comprehension here:
'''
def skype_clean(chat_history, exclusion_list):
    #skype = " ".join(chat_history)
    skype_clean = []
    skype_clean =[item for item in chat_history if not item.startswith("<")]
    return skype_clean

skype_clean = skype_clean(skype_content, exclusion_list)
skype_clean
# Out:
# ['we are getting air bnb 1000eur for self isolation + 500 for trip, 300 for covid tests, the solisiter says you will have to cover this, plus mamas loss in earnings for having to take ahmad to hospital in UK',
#  'you could pick us up in santander and we could self-isolate at your house, and mom didnt need to come to the UK, you are digging your own grave with your selfish childish behavior',
#  'we recorded the video with yesterdays call',
#  'You are with your mum. Under her care',
#  'you already know we are here in santander, we want to sail to england but its very expencive and difficult right now',
#  'just forget it, you dont want to help us',
#  'Ask the doctor to write a report with his condition',
#  'mama already told you everything we know',
#  '',
#  '',
#  'coaoxiclav',
#  'we dont have a writen report, we were given antibiotics and told he has lime',
# ...

# %%
#skype_clean
context = " \nNEXT MESSAGE: ".join([i for i in skype_clean])

context
# Out:
# 'we are getting air bnb 1000eur for self isolation + 500 for trip, 300 for covid tests, the solisiter says you will have to cover this, plus mamas loss in earnings for having to take ahmad to hospital in UK \nNEXT MESSAGE: you could pick us up in santander and we could self-isolate at your house, and mom didnt need to come to the UK, you are digging your own grave with your selfish childish behavior \nNEXT MESSAGE: we recorded the video with yesterdays call \nNEXT MESSAGE: You are with your mum. Under her care \nNEXT MESSAGE: you already know we are here in santander, we want to sail to england but its very expencive and difficult right now \nNEXT MESSAGE: just forget it, you dont want to help us \nNEXT MESSAGE: Ask the doctor to write a report with his condition \nNEXT MESSAGE: mama already told you everything we know \nNEXT MESSAGE:  \nNEXT MESSAGE:  \nNEXT MESSAGE: coaoxiclav \nNEXT MESSAGE: we dont have a writen report, we were given antibiotics and told he has lime \nNEXT MESSAG
# ...

# %%
#use this with actual text data:


import regex as re
# function to preprocess speech

def clean_easy(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

#or:
def clean(text):
    
    # removing paragraph numbers
    text = re.sub('[0-9]+.\t','',str(text))
    # removing new line characters
    #text = re.sub('\n ','',str(text))
    #text = re.sub('\n',' ',str(text))
    #text = re.sub('</e_m>',' ',str(text))
    
    # removing apostrophes
    text = re.sub("'s",'',str(text))
    # removing hyphens
    text = re.sub("-",' ',str(text))
    text = re.sub("— ",'',str(text))
    # removing quotation marks
    text = re.sub('\"','',str(text))
    # removing salutations
    text = re.sub("Mr\.",'Mr',str(text))
    text = re.sub("Mrs\.",'Mrs',str(text))
    # removing any reference to outside text
    text = re.sub("[\(\[].*?[\)\]]", "", str(text))
    # replacing emojis
    text = re.sub('\<ss type=like></ss>','good', str(text))
    text = re.sub('\<ss type=smile>:\)</ss>','smiling',str(text))
    text = re.sub('<ss type=sad>:</ss>','sad',str(text))
    text = re.sub('<ss type=sad>: </ss>','sad',str(text))
    text = re.sub('<ss type="heart">(heart)</ss>','love',str(text))
    text = re.sub('<b raw_pre=* raw_post=*>sarcasam</b>','evil',str(text))
    
    
    return text

# preprocessing speeches
context = clean(context)
context
# Out:
# 'we are getting air bnb 1000eur for self isolation + 500 for trip, 300 for covid tests, the solisiter says you will have to cover this, plus mamas loss in earnings for having to take ahmad to hospital in UK \nNEXT MESSAGE: you could pick us up in santander and we could self isolate at your house, and mom didnt need to come to the UK, you are digging your own grave with your selfish childish behavior \nNEXT MESSAGE: we recorded the video with yesterdays call \nNEXT MESSAGE: You are with your mum. Under her care \nNEXT MESSAGE: you already know we are here in santander, we want to sail to england but its very expencive and difficult right now \nNEXT MESSAGE: just forget it, you dont want to help us \nNEXT MESSAGE: Ask the doctor to write a report with his condition \nNEXT MESSAGE: mama already told you everything we know \nNEXT MESSAGE:  \nNEXT MESSAGE:  \nNEXT MESSAGE: coaoxiclav \nNEXT MESSAGE: we dont have a writen report, we were given antibiotics and told he has lime \nNEXT MESSAG
# ...

# %%
fname = r'data\hamade_skype_22052021.txt'
with open(fname, "w", encoding="utf-8") as f:
    f.write(context)

# %%
from IPython.display import Javascript
from nbconvert import HTMLExporter

def save_notebook():
    display(
        Javascript("IPython.notebook.save_notebook()"),
        include=['application/javascript']
    )

def output_HTML(read_file, output_file):
    import codecs
    import nbformat
    exporter = HTMLExporter()
    # read_file is '.ipynb', output_file is '.html'
    output_notebook = nbformat.read(read_file, as_version=4)
    output, resources = exporter.from_notebook_node(output_notebook)
    codecs.open(output_file, 'w', encoding='utf-8').write(output)

# %%
import time

save_notebook()
time.sleep(3)
current_file = 'skype_history_extractor.ipynb'
output_file = 'skype_history_extractor.html'
output_HTML(current_file, output_file)
